# %% [markdown]
# ## Importar bibliotecas

# %%
import pandas as pd
import numpy as np
from numpy.random import seed

# sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, Normalizer, MinMaxScaler, normalize, scale, LabelEncoder, OrdinalEncoder, OneHotEncoder
from sklearn.feature_selection import mutual_info_regression, f_regression, SelectKBest
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.multioutput import MultiOutputRegressor

# matplotlib, seaborn
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# tensorflow
import tensorflow as tf
from tensorflow import convert_to_tensor

# warnings
import warnings
warnings.filterwarnings("ignore")

# keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD, Adam, RMSprop
from keras.wrappers.scikit_learn import KerasRegressor
from keras.utils import to_categorical

# Counter
from collections import Counter

# seed
seed(1)
tf.random.set_seed(2)

# %% [markdown]
# ## Carga dataset

# %%
data = pd.read_csv('datasets/chile.csv')
print(data.columns)
print(data.shape)
data
# Out:
# Index(['data_id', 'iso', 'event_id_cnty', 'event_id_no_cnty', 'event_date',
#        'year', 'time_precision', 'event_type', 'sub_event_type', 'actor1',
#        'assoc_actor_1', 'inter1', 'actor2', 'assoc_actor_2', 'inter2',
#        'interaction', 'region', 'country', 'admin1', 'admin2', 'admin3',
#        'location', 'latitude', 'longitude', 'geo_precision', 'source',
#        'source_scale', 'notes', 'fatalities', 'timestamp', 'iso3'],
#       dtype='object')
# (6493, 31)
#       data_id  iso event_id_cnty  event_id_no_cnty        event_date  year  \
# 0     7409167  152       CHI6495              6495  11 December 2020  2020
# 1     7409168  152       CHI6496              6496  11 December 2020  2020
# 2     7409513  152       CHI6493              6493  11 December 2020  2020
# 3     7409341  152       CHI6494              6494  11 December 2020  2020
# 4     7409164  152       CHI6488              6488  10 December 2020  2020
# ...       ...  ...           ...               ...               ...   ...
# 6488  7355900  152       CHI5395              5395   03 January 2018  2018
# 6489  7355653  152       CHI5390              5390   02 January 2018  2018
# 6490  7359966  152       CHI5755              5755   02 January 2018  2018
# 6491  7360554  152       CHI5068              5068   01 January 2018  2018
# 6492  7360559  152       CHI5070              5070   01 January 2018  2018
#
#       time_precision              event_type                sub_event_type  \
# 0                  1                   Riots         Violent demonstration
# 1                  1                   Riots         Violent demonstration
# 2                  2                Protests              Peaceful protest
# 3                  1                Protests              Peaceful protest
# 4                  1  Strategic developments  Looting/property destruction
# ...              ...                     ...                           ...
# 6488               1                Protests              Peaceful protest
# 6489               1                Protests              Peaceful protest
# 6490               1                   Riots         Violent demonstration
# 6491               1  Strategic developments  Looting/property destruction
# 6492               1  Strategic developments  Looting/property destruction
#
#                           actor1  ...              location  latitude  \
# 0                Rioters (Chile)  ...          Mocha Island  -38.3807
# 1                Rioters (Chile)  ...              Santiago  -33.4569
# 2             Protesters (Chile)  ...                 Arica  -18.4746
# 3             Protesters (Chile)  ...             La Serena  -29.9045
# 4     Indigenous Militia (Chile)  ...                Canete  -37.8000
# ...                          ...  ...                   ...       ...
# 6488          Protesters (Chile)  ...           Providencia  -33.4311
# 6489          Protesters (Chile)  ...         Quinta Normal  -33.4419
# 6490             Rioters (Chile)  ...              Coquimbo  -29.9533
# 6491  Indigenous Militia (Chile)  ...  San Juan de la Costa  -40.5166
# 6492  Indigenous Militia (Chile)  ...             Rio Negro  -40.7958
#
#      longitude geo_precision  \
# 0     -73.9112             1
# 1     -70.6483             1
# 2     -70.2979             1
# 3     -71.2489             1
# 4     -73.3833             2
# ...        ...           ...
# 6488  -70.6045             1
# 6489  -70.6790             1
# 6490  -71.3395             1
# 6491  -73.4000             1
# 6492  -73.2177             1
#
#                                                  source          source_scale  \
# 0                                  El Sur; Biobio Chile           Subnational
# 1                        Biobio Chile; 24 Horas (Chile)              National
# 2                                     La Estrella Arica           Subnational
# 3                                        El Dia (Chile)              National
# 4     El Sur; La Estrella Concepcion; El Mercurio (C...  Subnational-National
# ...                                                 ...                   ...
# 6488                                       Biobio Chile              National
# 6489                                       Biobio Chile              National
# 6490                                     El Dia (Chile)              National
# 6491                                El Mercurio (Chile)              National
# 6492                                El Mercurio (Chile)              National
#
#                                                   notes fatalities  \
# 0     On 11 December 2020, in Mocha Island, Biobio r...          0
# 1     On 11 December 2020, in Santiago, Metropolitan...          0
# 2     Around 11 December 2020, in Arica, Arica y Par...          0
# 3     On 11 December 2020, in La Serena, Coquimbo re...          0
# 4     On 10 December 2020, in the rural area of Cane...          0
# ...                                                 ...        ...
# 6488  On 3 January 2018, in Providencia (Metropolita...          0
# 6489  On 2 January 2018, in Quinta Normal (Metropoli...          0
# 6490  On 2 January 2018, in Coquimbo (Coquimbo), a g...          0
# 6491  Property destruction: On 1 January 2018, in Sa...          0
# 6492  Property destruction: On 1 January 2018, in Ri...          0
#
#        timestamp iso3
# 0     1607982441  CHL
# 1     1607982441  CHL
# 2     1607982444  CHL
# 3     1607982442  CHL
# 4     1607982441  CHL
# ...          ...  ...
# 6488  1607554916  CHL
# 6489  1607554915  CHL
# 6490  1607554949  CHL
# 6491  1607554953  CHL
# 6492  1607554953  CHL
#
# [6493 rows x 31 columns]

# %% [markdown]
# ## Análisis exploratorio
#
# ### Número de categorías por atributo

# %%
for column in data.columns:
    print(column, ":", len(data[column].unique()))
# Out:
# data_id : 6493
# iso : 1
# event_id_cnty : 6493
# event_id_no_cnty : 6493
# event_date : 971
# year : 3
# time_precision : 3
# event_type : 6
# sub_event_type : 16
# actor1 : 38
# assoc_actor_1 : 248
# inter1 : 7
# actor2 : 20
# assoc_actor_2 : 111
# inter2 : 8
# interaction : 26
# region : 1
# country : 1
# admin1 : 17
# admin2 : 54
# admin3 : 243
# location : 371
# latitude : 371
# longitude : 367
# geo_precision : 3
# source : 307
# source_scale : 13
# notes : 6491
# fatalities : 5
# timestamp : 199
# iso3 : 1

# %% [markdown]
# ### Eliminar atributos inútiles

# %%
data = data.drop(['data_id','iso', "event_id_cnty", "event_id_no_cnty", "iso3", "country", "region"], axis=1)
print(len(data.columns))
print(data.columns)
# Out:
# 24
# Index(['event_date', 'year', 'time_precision', 'event_type', 'sub_event_type',
#        'actor1', 'assoc_actor_1', 'inter1', 'actor2', 'assoc_actor_2',
#        'inter2', 'interaction', 'admin1', 'admin2', 'admin3', 'location',
#        'latitude', 'longitude', 'geo_precision', 'source', 'source_scale',
#        'notes', 'fatalities', 'timestamp'],
#       dtype='object')

# %% [markdown]
# Cambio de nombre columna:
#
# * admin1 = región
# * Se mantiene event_type

# %%
data = data.rename(columns={"admin1": "region"})

# %% [markdown]
# ### Algunas cuentas por atributo

# %%
see = ["year", "region", "event_type"]

for s in see:
  gr = data.groupby(s).size().nlargest(50).reset_index(name='counts')
  fig, ax = plt.subplots(figsize=(15, 5),nrows=1)
  sns.barplot(data=gr, x=s, y='counts', palette="Blues_d",ax=ax)
  ax.set_title('Violaciones DDHH por ' + s)
  ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
  plt.show()
  print("")

cont_predictors_names = ['event_date', 'year', 'time_precision', 'sub_event_type',
       'actor1', 'assoc_actor_1', 'inter1', 'actor2', 'assoc_actor_2',
       'inter2', 'interaction', 'region', 'admin2', 'admin3',
       'latitude', 'longitude', 'geo_precision', 'source', 'source_scale',
       'notes', 'fatalities', 'timestamp']

classes = ["region", "event_type"]

# %% [markdown]
# ### Split dataset
#
# A predecir:
#
# * Tipo de evento (event_type)
# * Lugar (region)
#
# LabelEncoder para encoding de atributos categóricos

# %%
label_encoders = dict()
are_object = list()

for column in data.columns:
  if str(data[column].dtype) == "object":
      data[column] = data[column].astype('|S')
      are_object.append(column)

print("Son de tipo objeto:", len(are_object))

for is_object in are_object:
  label_encoders[is_object] = LabelEncoder()
  data[is_object] = label_encoders[is_object].fit_transform(data[is_object])

features = ['event_date', 'year', 'time_precision', 'sub_event_type',
       'actor1', 'assoc_actor_1', 'inter1', 'actor2', 'assoc_actor_2',
       'inter2', 'interaction', 'admin2', 'admin3',
       'latitude', 'longitude', 'geo_precision', 'source', 'source_scale',
       'notes', 'fatalities', 'timestamp']

predict = ["region", "event_type"]

X = data[features]
Y = data[predict]

X_train_full, X_test, Y_train_full, Y_test = train_test_split(X, Y, test_size=0.5, random_state=0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train_full, Y_train_full, test_size=0.5, random_state=0)
# Out:
# Son de tipo objeto: 14

# %% [markdown]
# # Selección y regularización de atributos

# %%
best_attributes = list()
worst_attributes = list()

# %% [markdown]
# ## Ridge

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

for p in predict:
  print("Atributo:", p)
  
  alphas_ridge = list(np.logspace(-5, 5, num=20, base=10))
  active_ridge = []
  coef_matrix = []

  idx = 0
  coef_matrix = np.zeros((X_train.shape[1],len(alphas_ridge)))

  for alpha in alphas_ridge:
    modelo_ridge = Ridge(alpha)
    modelo_ridge.fit(X_train, Y_train[p])
    coefs_ridge = modelo_ridge.coef_
    active_ridge.append(len(coefs_ridge[coefs_ridge>0.001]))
    coef_matrix[:,idx] = coefs_ridge
    idx = idx + 1

  neg_log_alphas = -np.log(alphas_ridge)
  fig, ax = plt.subplots(figsize=(16,6),nrows=1, ncols=1)

  from_plot = 0
  for idx in range(X_train.shape[1]):
    sns.lineplot(x=neg_log_alphas[from_plot:],y=coef_matrix[idx,from_plot:],ax=ax)
  plt.show()

  importance = coef_matrix>0.001
  importance = np.sum(importance,axis=1)
  print(importance.shape)
  idx_imp = np.argsort(importance)
  top = idx_imp[-10:]
  names = X_train.columns
  names_top = [names[idx] for idx in top]

  bottom = idx_imp[:10]
  names_bottom = [names[idx] for idx in bottom]

  print("\nMás Importantes:\n")
  print(names_top[:5])
  print(names_top[5:])

  print("\nMenos Importantes:\n")
  print(names_bottom[:5])
  print(names_bottom[5:])

  print("\n")
  
  best_attributes.append(names_top[5:])
  best_attributes.append(names_top[:5])

  best_attributes.append(names_bottom[5:])
  best_attributes.append(names_bottom[:5])
# Out:
# Atributo: region
# (21,)
#
# Más Importantes:
#
# ['interaction', 'time_precision', 'actor1', 'admin2', 'admin3']
# ['latitude', 'longitude', 'sub_event_type', 'source', 'year']
#
# Menos Importantes:
#
# ['event_date', 'notes', 'source_scale', 'geo_precision', 'inter2']
# ['timestamp', 'assoc_actor_2', 'inter1', 'actor2', 'fatalities']
#
#
# Atributo: event_type
# (21,)
#
# Más Importantes:
#
# ['geo_precision', 'fatalities', 'latitude', 'interaction', 'sub_event_type']
# ['time_precision', 'source_scale', 'year', 'inter2', 'actor1']
#
# Menos Importantes:
#
# ['event_date', 'notes', 'source', 'longitude', 'admin3']
# ['admin2', 'assoc_actor_2', 'timestamp', 'inter1', 'assoc_actor_1']

# %% [markdown]
# ## Correlación de Pearson

# %%
plt.figure(figsize=(12,10))

corr_data = pd.concat([X_train, Y_train], axis=1)

cor = corr_data.corr()

sns.heatmap(cor, cmap=plt.cm.Greens)
plt.show()

for p in predict:
  cor_target = abs(cor[p])
  target_features = cor_target.sort_values().to_frame()
  
  print("Correlación - Menos importantes:\n")
  print(target_features[:4])
  print("\n")
  worst_attributes.append(target_features[p][:4].index.tolist())

  print("Correlación - Más importantes:\n")
  print(target_features[-4:])
  print("\n\n")
  
  best_attributes.append(target_features[p][-4:].index.tolist())
# Out:
# Correlación - Menos importantes:
#
#                   region
# time_precision  0.008243
# event_type      0.008305
# assoc_actor_1   0.009214
# latitude        0.010647
#
#
# Correlación - Más importantes:
#
#                 region
# source_scale  0.271092
# admin3        0.442793
# admin2        0.713222
# region        1.000000
#
#
#
# Correlación - Menos importantes:
#
#                 event_type
# region            0.008305
# admin2            0.020198
# sub_event_type    0.023443
# admin3            0.035432
#
#
# Correlación - Más importantes:
#
#             event_type
# inter2        0.644077
# actor2        0.672876
# inter1        0.780674
# event_type    1.000000

# %% [markdown]
# ## Mutual info regression
# ## f regression

# %%
print("Peores atributos\n")

for p in predict:
  print("Feature:", p)
  # mutual_info_regression
  selector = SelectKBest(mutual_info_regression, k=18)
  selector.fit(X_train, Y_train[p])

  cols = selector.get_support(indices=True)
  features_df_new = X_train.iloc[:,cols].columns
  worst_attr = set(list(features)) - set(list(features_df_new))
  print("Mutual regression info:", worst_attr)
  worst_attributes.append(list(worst_attr))

  # f_regression
  selector = SelectKBest(f_regression, k=18)
  selector.fit(X_train, Y_train[p])

  cols = selector.get_support(indices=True)
  features_df_new = X_train.iloc[:,cols].columns
  worst_attr = set(list(features)) - set(list(features_df_new))
  print("f regression:", worst_attr)
  worst_attributes.append(list(worst_attr))
  print("\n")
# Out:
# Peores atributos
#
# Feature: region
# Mutual regression info: {'time_precision', 'fatalities', 'year'}
# f regression: {'time_precision', 'assoc_actor_1', 'latitude'}
#
#
# Feature: event_type
# Mutual regression info: {'time_precision', 'fatalities', 'source_scale'}
# f regression: {'admin2', 'admin3', 'sub_event_type'}

# %% [markdown]
# ## Mejores y peores atributos, cuenta final

# %%
best = list()

for i in best_attributes:
  best += i

counter_best = Counter(best)

import heapq
from operator import itemgetter

n = 5

topitems = heapq.nlargest(n, counter_best.items(), key=itemgetter(1))  # Use .iteritems() on Py2
best = dict(topitems)

print("Best attributes:")
print(best)
print("\n")

worst = list()

for i in worst_attributes:
  worst += i

counter_worst = Counter(worst)

import heapq
from operator import itemgetter

n = 5

topitems = heapq.nlargest(n, counter_worst.items(), key=itemgetter(1))  # Use .iteritems() on Py2
worst = dict(topitems)

print("Worst attributes:")
print(worst)
# Out:
# Best attributes:
# {'admin2': 3, 'admin3': 3, 'inter1': 3, 'source_scale': 3, 'inter2': 3}
#
#
# Worst attributes:
# {'time_precision': 4, 'assoc_actor_1': 2, 'latitude': 2, 'admin2': 2, 'sub_event_type': 2}

# %% [markdown]
# > Se decide no sacar estos atributos, a menos que los algoritmos que se ocupen den malos resultados.

# %% [markdown]
# Distribuciones de los atributos

# %%
fig, axes = plt.subplots(figsize=(16,12), nrows=6, ncols=4)
for i, column in enumerate(data.columns):
  sns.distplot(data[column], hist=True, rug=False, kde=True, ax=axes[i//4,i%4])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Estandarización

# %%
for c in X_train.columns:
  X_train[c] = scale(X_train[c])
  X_test[c] = scale(X_test[c])
  X_val[c] = scale(X_val[c])

for c in Y_train.columns:
  Y_train[c] = scale(Y_train[c])
  Y_test[c] = scale(Y_test[c])
  Y_val[c] = scale(Y_val[c])

# %% [markdown]
# ## Distribuciones estandarizadas

# %%
fig, axes = plt.subplots(figsize=(16,12), nrows=6, ncols=4)
for i, column in enumerate(X_train.columns):
  sns.distplot(X_train[column], hist=True, rug=False, kde=True, ax=axes[i//4,i%4])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comprobar encoding

# %%
print(data.dtypes)
print(X_train.shape)
print(X_val.shape)
# Out:
# event_date          int64
# year                int64
# time_precision      int64
# event_type          int64
# sub_event_type      int64
# actor1              int64
# assoc_actor_1       int64
# inter1              int64
# actor2              int64
# assoc_actor_2       int64
# inter2              int64
# interaction         int64
# region              int64
# admin2              int64
# admin3              int64
# location            int64
# latitude          float64
# longitude         float64
# geo_precision       int64
# source              int64
# source_scale        int64
# notes               int64
# fatalities          int64
# timestamp           int64
# dtype: object
# (1623, 21)
# (1623, 21)

# %% [markdown]
# # Modelos
#
# * Red Neuronal Feed-Forward
# * Random Forest
# * AdaBoost

# %% [markdown]
# # Validación de los modelos: árbol de máxima profundidad

# %%
tree = DecisionTreeRegressor(random_state=0)
print("Mejor árbol:")

tree.fit(X_train, Y_train)
print("Profundidad", tree.tree_.max_depth)
predictions = tree.predict(X_test)
print("MSE:", mean_squared_error(Y_test, predictions))

predictions = tree.predict(X_val)
print("MSE val:", mean_squared_error(Y_val, predictions))
print("\n")

for _ in range(2):
  tree = DecisionTreeRegressor(random_state=0, max_depth=tree.tree_.max_depth-1)
  print("Árbol podado:")

  tree.fit(X_train, Y_train)
  print("Profundidad", tree.tree_.max_depth)
  predictions = tree.predict(X_test)
  print("MSE:", mean_squared_error(Y_test, predictions))

  predictions = tree.predict(X_val)
  print("MSE val:", mean_squared_error(Y_val, predictions))
  print("\n")
# Out:
# Mejor árbol:
# Profundidad 26
# MSE: 0.1562103179952845
# MSE val: 0.2640887061753108
#
#
# Árbol podado:
# Profundidad 25
# MSE: 0.14220871089098341
# MSE val: 0.25065892060997663
#
#
# Árbol podado:
# Profundidad 24
# MSE: 0.14720513714656472
# MSE val: 0.25029286480896684

# %% [markdown]
# ## Red Neuronal Feed-Forward

# %%
def create_model(optimizer='rmsprop', nneuron=24, n_outputs=2):
  
    model = Sequential()
    model.add(Dense(nneuron, input_shape=(X_train.shape[1],), kernel_initializer='normal', activation='relu'))
    model.add(Dense(int(nneuron*1.5), kernel_initializer='normal', activation='relu'))
    model.add(Dense(n_outputs, activation="linear", kernel_initializer='normal'))

    if optimizer == "rmsprop":
      opt = RMSprop()
    elif optimizer == "adam":
      opt = Adam()
    elif optimizer == "SGD":
      opt = SGD()
    else:
      return "error"

    model.compile(
        loss='mse',
        metrics=[tf.keras.metrics.RootMeanSquaredError(),
                 tf.keras.metrics.MeanAbsolutePercentageError(),
                 ],
        optimizer=opt)
    
    return model

model = KerasRegressor(build_fn=create_model, epochs=20, batch_size=5, verbose=0)

optimizers = ['SGD', 'rmsprop', 'adam']
epochs = [10, 50]
batches = [5, 10]
nneurons = [24]

param_grid = dict(optimizer=optimizers, epochs=epochs, batch_size=batches, nneuron=nneurons)
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=10)
grid_result = grid.fit(X_train, Y_train)

print("Best: %f con %s" % (grid_result.best_score_, grid_result.best_params_))

means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) con: %r" % (mean, stdev, param))
# Out:
# Best: -0.114030 con {'batch_size': 5, 'epochs': 50, 'nneuron': 24, 'optimizer': 'adam'}
# -0.266520 (0.065987) con: {'batch_size': 5, 'epochs': 10, 'nneuron': 24, 'optimizer': 'SGD'}
# -0.231836 (0.063405) con: {'batch_size': 5, 'epochs': 10, 'nneuron': 24, 'optimizer': 'rmsprop'}
# -0.203784 (0.054288) con: {'batch_size': 5, 'epochs': 10, 'nneuron': 24, 'optimizer': 'adam'}
# -0.150500 (0.047495) con: {'batch_size': 5, 'epochs': 50, 'nneuron': 24, 'optimizer': 'SGD'}
# -0.129635 (0.044668) con: {'batch_size': 5, 'epochs': 50, 'nneuron': 24, 'optimizer': 'rmsprop'}
# -0.114030 (0.051414) con: {'batch_size': 5, 'epochs': 50, 'nneuron': 24, 'optimizer': 'adam'}
# -0.334116 (0.072680) con: {'batch_size': 10, 'epochs': 10, 'nneuron': 24, 'optimizer': 'SGD'}
# -0.242181 (0.057495) con: {'batch_size': 10, 'epochs': 10, 'nneuron': 24, 'optimizer': 'rmsprop'}
# -0.226676 (0.062675) con: {'batch_size': 10, 'epochs': 10, 'nneuron': 24, 'optimizer': 'adam'}
# -0.186793 (0.049738) con: {'batch_size': 10, 'epochs': 50, 'nneuron': 24, 'optimizer': 'SGD'}
# -0.141658 (0.043589) con: {'batch_size': 10, 'epochs': 50, 'nneuron': 24, 'optimizer': 'rmsprop'}
# -0.144720 (0.037548) con: {'batch_size': 10, 'epochs': 50, 'nneuron': 24, 'optimizer': 'adam'}

# %% [markdown]
# # Mejor red neuronal

# %%
optimizer = grid_result.best_params_["optimizer"]
nneuron = grid_result.best_params_["nneuron"]
batch_size = grid_result.best_params_["batch_size"]
epochs = grid_result.best_params_["epochs"] * 10

model = create_model(optimizer=optimizer, nneuron=nneuron)
history = model.fit(X_train, Y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.5935 - root_mean_squared_error: 0.7704 - mean_absolute_percentage_error: 69.8519 - val_loss: 0.3599 - val_root_mean_squared_error: 0.5999 - val_mean_absolute_percentage_error: 55.7757
# Epoch 2/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.3026 - root_mean_squared_error: 0.5501 - mean_absolute_percentage_error: 53.6453 - val_loss: 0.3006 - val_root_mean_squared_error: 0.5483 - val_mean_absolute_percentage_error: 53.9129
# Epoch 3/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.2666 - root_mean_squared_error: 0.5163 - mean_absolute_percentage_error: 51.0974 - val_loss: 0.2789 - val_root_mean_squared_error: 0.5281 - val_mean_absolute_percentage_error: 53.8417
# Epoch 4/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.2397 - root_mean_squared_error: 0.4895 - mean_absolute_percentage_error: 49.9591 - val_loss: 0.2603 - val_root_mean_squared_error: 0.5102 - val_mean_absolute_percentage_error: 52.8324
# Epoch 5/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.2216 - root_mean_squared_error: 0.4708 - mean_absolute_percentage_error: 48.7338 - val_loss: 0.2420 - val_root_mean_squared_error: 0.4919 - val_mean_absolute_percentage_error: 50.4773
# Epoch 6/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.2045 - root_mean_squared_error: 0.4522 - mean_absolute_percentage_error: 47.1846 - val_loss: 0.2321 - val_root_mean_squared_error: 0.4818 - val_mean_absolute_percentage_error: 51.5328
# Epoch 7/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1915 - root_mean_squared_error: 0.4376 - mean_absolute_percentage_error: 45.9454 - val_loss: 0.2247 - val_root_mean_squared_error: 0.4741 - val_mean_absolute_percentage_error: 51.3157
# Epoch 8/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1801 - root_mean_squared_error: 0.4244 - mean_absolute_percentage_error: 46.1281 - val_loss: 0.2209 - val_root_mean_squared_error: 0.4700 - val_mean_absolute_percentage_error: 49.2522
# Epoch 9/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1698 - root_mean_squared_error: 0.4120 - mean_absolute_percentage_error: 44.0955 - val_loss: 0.2162 - val_root_mean_squared_error: 0.4649 - val_mean_absolute_percentage_error: 49.0375
# Epoch 10/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1634 - root_mean_squared_error: 0.4043 - mean_absolute_percentage_error: 43.7781 - val_loss: 0.2064 - val_root_mean_squared_error: 0.4543 - val_mean_absolute_percentage_error: 48.6869
# Epoch 11/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1527 - root_mean_squared_error: 0.3907 - mean_absolute_percentage_error: 42.1644 - val_loss: 0.2073 - val_root_mean_squared_error: 0.4553 - val_mean_absolute_percentage_error: 52.0562
# Epoch 12/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1471 - root_mean_squared_error: 0.3835 - mean_absolute_percentage_error: 41.1561 - val_loss: 0.2052 - val_root_mean_squared_error: 0.4530 - val_mean_absolute_percentage_error: 48.4477
# Epoch 13/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1429 - root_mean_squared_error: 0.3780 - mean_absolute_percentage_error: 40.1657 - val_loss: 0.1967 - val_root_mean_squared_error: 0.4435 - val_mean_absolute_percentage_error: 44.3266
# Epoch 14/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1374 - root_mean_squared_error: 0.3707 - mean_absolute_percentage_error: 38.5552 - val_loss: 0.1947 - val_root_mean_squared_error: 0.4413 - val_mean_absolute_percentage_error: 45.3268
# Epoch 15/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1300 - root_mean_squared_error: 0.3605 - mean_absolute_percentage_error: 37.6804 - val_loss: 0.1956 - val_root_mean_squared_error: 0.4423 - val_mean_absolute_percentage_error: 48.4380
# Epoch 16/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1258 - root_mean_squared_error: 0.3546 - mean_absolute_percentage_error: 37.5616 - val_loss: 0.1886 - val_root_mean_squared_error: 0.4342 - val_mean_absolute_percentage_error: 46.0439
# Epoch 17/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1238 - root_mean_squared_error: 0.3518 - mean_absolute_percentage_error: 36.1732 - val_loss: 0.1850 - val_root_mean_squared_error: 0.4301 - val_mean_absolute_percentage_error: 44.3933
# Epoch 18/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1169 - root_mean_squared_error: 0.3419 - mean_absolute_percentage_error: 37.0571 - val_loss: 0.1891 - val_root_mean_squared_error: 0.4348 - val_mean_absolute_percentage_error: 42.8865
# Epoch 19/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1149 - root_mean_squared_error: 0.3390 - mean_absolute_percentage_error: 35.0979 - val_loss: 0.1882 - val_root_mean_squared_error: 0.4339 - val_mean_absolute_percentage_error: 42.1886
# Epoch 20/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1130 - root_mean_squared_error: 0.3362 - mean_absolute_percentage_error: 34.5986 - val_loss: 0.1793 - val_root_mean_squared_error: 0.4235 - val_mean_absolute_percentage_error: 41.4997
# Epoch 21/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1079 - root_mean_squared_error: 0.3284 - mean_absolute_percentage_error: 34.1619 - val_loss: 0.1765 - val_root_mean_squared_error: 0.4201 - val_mean_absolute_percentage_error: 40.4585
# Epoch 22/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1069 - root_mean_squared_error: 0.3269 - mean_absolute_percentage_error: 33.6264 - val_loss: 0.1788 - val_root_mean_squared_error: 0.4229 - val_mean_absolute_percentage_error: 39.9158
# Epoch 23/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.1024 - root_mean_squared_error: 0.3200 - mean_absolute_percentage_error: 32.9105 - val_loss: 0.1713 - val_root_mean_squared_error: 0.4139 - val_mean_absolute_percentage_error: 41.7439
# Epoch 24/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0996 - root_mean_squared_error: 0.3155 - mean_absolute_percentage_error: 32.9313 - val_loss: 0.1664 - val_root_mean_squared_error: 0.4079 - val_mean_absolute_percentage_error: 41.4419
# Epoch 25/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0991 - root_mean_squared_error: 0.3148 - mean_absolute_percentage_error: 32.4942 - val_loss: 0.1655 - val_root_mean_squared_error: 0.4069 - val_mean_absolute_percentage_error: 39.8071
# Epoch 26/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0928 - root_mean_squared_error: 0.3046 - mean_absolute_percentage_error: 31.1764 - val_loss: 0.1651 - val_root_mean_squared_error: 0.4063 - val_mean_absolute_percentage_error: 37.1048
# Epoch 27/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0910 - root_mean_squared_error: 0.3016 - mean_absolute_percentage_error: 30.6010 - val_loss: 0.1649 - val_root_mean_squared_error: 0.4060 - val_mean_absolute_percentage_error: 38.2004
# Epoch 28/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0883 - root_mean_squared_error: 0.2972 - mean_absolute_percentage_error: 30.5183 - val_loss: 0.1563 - val_root_mean_squared_error: 0.3954 - val_mean_absolute_percentage_error: 36.0370
# Epoch 29/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0870 - root_mean_squared_error: 0.2950 - mean_absolute_percentage_error: 30.0709 - val_loss: 0.1538 - val_root_mean_squared_error: 0.3921 - val_mean_absolute_percentage_error: 36.7847
# Epoch 30/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0860 - root_mean_squared_error: 0.2932 - mean_absolute_percentage_error: 29.9886 - val_loss: 0.1545 - val_root_mean_squared_error: 0.3931 - val_mean_absolute_percentage_error: 35.6732
# Epoch 31/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0794 - root_mean_squared_error: 0.2817 - mean_absolute_percentage_error: 28.4674 - val_loss: 0.1528 - val_root_mean_squared_error: 0.3908 - val_mean_absolute_percentage_error: 36.6750
# Epoch 32/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0784 - root_mean_squared_error: 0.2800 - mean_absolute_percentage_error: 29.2048 - val_loss: 0.1542 - val_root_mean_squared_error: 0.3926 - val_mean_absolute_percentage_error: 37.2848
# Epoch 33/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0766 - root_mean_squared_error: 0.2767 - mean_absolute_percentage_error: 27.9535 - val_loss: 0.1493 - val_root_mean_squared_error: 0.3863 - val_mean_absolute_percentage_error: 34.8066
# Epoch 34/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0751 - root_mean_squared_error: 0.2740 - mean_absolute_percentage_error: 28.6633 - val_loss: 0.1508 - val_root_mean_squared_error: 0.3883 - val_mean_absolute_percentage_error: 34.5135
# Epoch 35/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0731 - root_mean_squared_error: 0.2703 - mean_absolute_percentage_error: 27.2626 - val_loss: 0.1473 - val_root_mean_squared_error: 0.3839 - val_mean_absolute_percentage_error: 36.1209
# Epoch 36/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0710 - root_mean_squared_error: 0.2664 - mean_absolute_percentage_error: 26.6283 - val_loss: 0.1464 - val_root_mean_squared_error: 0.3826 - val_mean_absolute_percentage_error: 39.2282
# Epoch 37/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0701 - root_mean_squared_error: 0.2647 - mean_absolute_percentage_error: 27.0498 - val_loss: 0.1431 - val_root_mean_squared_error: 0.3782 - val_mean_absolute_percentage_error: 34.4181
# Epoch 38/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0660 - root_mean_squared_error: 0.2568 - mean_absolute_percentage_error: 26.6301 - val_loss: 0.1509 - val_root_mean_squared_error: 0.3885 - val_mean_absolute_percentage_error: 38.6937
# Epoch 39/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0648 - root_mean_squared_error: 0.2545 - mean_absolute_percentage_error: 26.8335 - val_loss: 0.1466 - val_root_mean_squared_error: 0.3829 - val_mean_absolute_percentage_error: 34.9559
# Epoch 40/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0651 - root_mean_squared_error: 0.2552 - mean_absolute_percentage_error: 26.3579 - val_loss: 0.1442 - val_root_mean_squared_error: 0.3798 - val_mean_absolute_percentage_error: 34.4561
# Epoch 41/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0613 - root_mean_squared_error: 0.2477 - mean_absolute_percentage_error: 25.3670 - val_loss: 0.1479 - val_root_mean_squared_error: 0.3846 - val_mean_absolute_percentage_error: 34.5630
# Epoch 42/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0604 - root_mean_squared_error: 0.2458 - mean_absolute_percentage_error: 25.4280 - val_loss: 0.1442 - val_root_mean_squared_error: 0.3797 - val_mean_absolute_percentage_error: 38.0730
# Epoch 43/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0590 - root_mean_squared_error: 0.2429 - mean_absolute_percentage_error: 25.1293 - val_loss: 0.1494 - val_root_mean_squared_error: 0.3865 - val_mean_absolute_percentage_error: 42.5471
# Epoch 44/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0571 - root_mean_squared_error: 0.2389 - mean_absolute_percentage_error: 25.2598 - val_loss: 0.1408 - val_root_mean_squared_error: 0.3753 - val_mean_absolute_percentage_error: 38.3357
# Epoch 45/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0569 - root_mean_squared_error: 0.2386 - mean_absolute_percentage_error: 25.1561 - val_loss: 0.1501 - val_root_mean_squared_error: 0.3874 - val_mean_absolute_percentage_error: 34.5701
# Epoch 46/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0551 - root_mean_squared_error: 0.2348 - mean_absolute_percentage_error: 25.3116 - val_loss: 0.1438 - val_root_mean_squared_error: 0.3792 - val_mean_absolute_percentage_error: 36.3903
# Epoch 47/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0526 - root_mean_squared_error: 0.2294 - mean_absolute_percentage_error: 24.8766 - val_loss: 0.1445 - val_root_mean_squared_error: 0.3801 - val_mean_absolute_percentage_error: 33.3602
# Epoch 48/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0525 - root_mean_squared_error: 0.2292 - mean_absolute_percentage_error: 23.7510 - val_loss: 0.1398 - val_root_mean_squared_error: 0.3739 - val_mean_absolute_percentage_error: 32.1070
# Epoch 49/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0492 - root_mean_squared_error: 0.2217 - mean_absolute_percentage_error: 23.4090 - val_loss: 0.1528 - val_root_mean_squared_error: 0.3908 - val_mean_absolute_percentage_error: 36.7593
# Epoch 50/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0500 - root_mean_squared_error: 0.2236 - mean_absolute_percentage_error: 23.6871 - val_loss: 0.1418 - val_root_mean_squared_error: 0.3766 - val_mean_absolute_percentage_error: 34.5111
# Epoch 51/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0490 - root_mean_squared_error: 0.2214 - mean_absolute_percentage_error: 23.8972 - val_loss: 0.1395 - val_root_mean_squared_error: 0.3735 - val_mean_absolute_percentage_error: 31.2040
# Epoch 52/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0459 - root_mean_squared_error: 0.2143 - mean_absolute_percentage_error: 23.5073 - val_loss: 0.1459 - val_root_mean_squared_error: 0.3819 - val_mean_absolute_percentage_error: 34.4190
# Epoch 53/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0477 - root_mean_squared_error: 0.2183 - mean_absolute_percentage_error: 24.1297 - val_loss: 0.1378 - val_root_mean_squared_error: 0.3712 - val_mean_absolute_percentage_error: 31.6555
# Epoch 54/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0457 - root_mean_squared_error: 0.2138 - mean_absolute_percentage_error: 23.9559 - val_loss: 0.1390 - val_root_mean_squared_error: 0.3728 - val_mean_absolute_percentage_error: 32.2172
# Epoch 55/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0449 - root_mean_squared_error: 0.2120 - mean_absolute_percentage_error: 23.2784 - val_loss: 0.1431 - val_root_mean_squared_error: 0.3783 - val_mean_absolute_percentage_error: 39.3798
# Epoch 56/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0444 - root_mean_squared_error: 0.2107 - mean_absolute_percentage_error: 23.1062 - val_loss: 0.1336 - val_root_mean_squared_error: 0.3655 - val_mean_absolute_percentage_error: 31.4472
# Epoch 57/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0422 - root_mean_squared_error: 0.2055 - mean_absolute_percentage_error: 22.7556 - val_loss: 0.1351 - val_root_mean_squared_error: 0.3676 - val_mean_absolute_percentage_error: 31.0581
# Epoch 58/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0412 - root_mean_squared_error: 0.2029 - mean_absolute_percentage_error: 22.3117 - val_loss: 0.1359 - val_root_mean_squared_error: 0.3686 - val_mean_absolute_percentage_error: 32.7925
# Epoch 59/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0414 - root_mean_squared_error: 0.2035 - mean_absolute_percentage_error: 22.7012 - val_loss: 0.1348 - val_root_mean_squared_error: 0.3671 - val_mean_absolute_percentage_error: 31.2530
# Epoch 60/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0401 - root_mean_squared_error: 0.2002 - mean_absolute_percentage_error: 23.1013 - val_loss: 0.1477 - val_root_mean_squared_error: 0.3843 - val_mean_absolute_percentage_error: 36.2067
# Epoch 61/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0394 - root_mean_squared_error: 0.1984 - mean_absolute_percentage_error: 22.0216 - val_loss: 0.1519 - val_root_mean_squared_error: 0.3897 - val_mean_absolute_percentage_error: 30.3122
# Epoch 62/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0390 - root_mean_squared_error: 0.1974 - mean_absolute_percentage_error: 21.7084 - val_loss: 0.1332 - val_root_mean_squared_error: 0.3649 - val_mean_absolute_percentage_error: 30.7382
# Epoch 63/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0374 - root_mean_squared_error: 0.1934 - mean_absolute_percentage_error: 21.8261 - val_loss: 0.1298 - val_root_mean_squared_error: 0.3603 - val_mean_absolute_percentage_error: 31.7838
# Epoch 64/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0369 - root_mean_squared_error: 0.1921 - mean_absolute_percentage_error: 21.7130 - val_loss: 0.1443 - val_root_mean_squared_error: 0.3799 - val_mean_absolute_percentage_error: 31.4421
# Epoch 65/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0358 - root_mean_squared_error: 0.1891 - mean_absolute_percentage_error: 22.3234 - val_loss: 0.1429 - val_root_mean_squared_error: 0.3781 - val_mean_absolute_percentage_error: 33.8852
# Epoch 66/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0347 - root_mean_squared_error: 0.1864 - mean_absolute_percentage_error: 21.5895 - val_loss: 0.1292 - val_root_mean_squared_error: 0.3594 - val_mean_absolute_percentage_error: 31.8596
# Epoch 67/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0372 - root_mean_squared_error: 0.1928 - mean_absolute_percentage_error: 22.1021 - val_loss: 0.1396 - val_root_mean_squared_error: 0.3736 - val_mean_absolute_percentage_error: 32.6860
# Epoch 68/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0346 - root_mean_squared_error: 0.1859 - mean_absolute_percentage_error: 21.4307 - val_loss: 0.1322 - val_root_mean_squared_error: 0.3637 - val_mean_absolute_percentage_error: 30.9887
# Epoch 69/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0328 - root_mean_squared_error: 0.1810 - mean_absolute_percentage_error: 20.7113 - val_loss: 0.1385 - val_root_mean_squared_error: 0.3722 - val_mean_absolute_percentage_error: 33.8950
# Epoch 70/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0350 - root_mean_squared_error: 0.1871 - mean_absolute_percentage_error: 22.0115 - val_loss: 0.1371 - val_root_mean_squared_error: 0.3702 - val_mean_absolute_percentage_error: 33.6631
# Epoch 71/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0335 - root_mean_squared_error: 0.1829 - mean_absolute_percentage_error: 20.7862 - val_loss: 0.1321 - val_root_mean_squared_error: 0.3634 - val_mean_absolute_percentage_error: 32.8249
# Epoch 72/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0322 - root_mean_squared_error: 0.1795 - mean_absolute_percentage_error: 21.1349 - val_loss: 0.1344 - val_root_mean_squared_error: 0.3666 - val_mean_absolute_percentage_error: 30.4453
# Epoch 73/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0316 - root_mean_squared_error: 0.1778 - mean_absolute_percentage_error: 20.8701 - val_loss: 0.1285 - val_root_mean_squared_error: 0.3584 - val_mean_absolute_percentage_error: 30.0841
# Epoch 74/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0324 - root_mean_squared_error: 0.1799 - mean_absolute_percentage_error: 20.8677 - val_loss: 0.1304 - val_root_mean_squared_error: 0.3611 - val_mean_absolute_percentage_error: 32.2642
# Epoch 75/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0327 - root_mean_squared_error: 0.1807 - mean_absolute_percentage_error: 21.0255 - val_loss: 0.1383 - val_root_mean_squared_error: 0.3719 - val_mean_absolute_percentage_error: 31.5022
# Epoch 76/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0299 - root_mean_squared_error: 0.1729 - mean_absolute_percentage_error: 21.1956 - val_loss: 0.1393 - val_root_mean_squared_error: 0.3733 - val_mean_absolute_percentage_error: 33.7768
# Epoch 77/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0304 - root_mean_squared_error: 0.1743 - mean_absolute_percentage_error: 20.8655 - val_loss: 0.1316 - val_root_mean_squared_error: 0.3628 - val_mean_absolute_percentage_error: 28.9928
# Epoch 78/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0304 - root_mean_squared_error: 0.1744 - mean_absolute_percentage_error: 20.1759 - val_loss: 0.1352 - val_root_mean_squared_error: 0.3678 - val_mean_absolute_percentage_error: 32.2655
# Epoch 79/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0296 - root_mean_squared_error: 0.1719 - mean_absolute_percentage_error: 20.9154 - val_loss: 0.1300 - val_root_mean_squared_error: 0.3605 - val_mean_absolute_percentage_error: 31.7215
# Epoch 80/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0300 - root_mean_squared_error: 0.1731 - mean_absolute_percentage_error: 21.1222 - val_loss: 0.1302 - val_root_mean_squared_error: 0.3609 - val_mean_absolute_percentage_error: 31.3382
# Epoch 81/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0319 - root_mean_squared_error: 0.1787 - mean_absolute_percentage_error: 21.5904 - val_loss: 0.1326 - val_root_mean_squared_error: 0.3641 - val_mean_absolute_percentage_error: 31.0929
# Epoch 82/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0284 - root_mean_squared_error: 0.1686 - mean_absolute_percentage_error: 20.3496 - val_loss: 0.1315 - val_root_mean_squared_error: 0.3627 - val_mean_absolute_percentage_error: 31.9006
# Epoch 83/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0285 - root_mean_squared_error: 0.1689 - mean_absolute_percentage_error: 20.4114 - val_loss: 0.1338 - val_root_mean_squared_error: 0.3658 - val_mean_absolute_percentage_error: 31.5632
# Epoch 84/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0279 - root_mean_squared_error: 0.1671 - mean_absolute_percentage_error: 20.1515 - val_loss: 0.1304 - val_root_mean_squared_error: 0.3612 - val_mean_absolute_percentage_error: 30.4509
# Epoch 85/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0266 - root_mean_squared_error: 0.1632 - mean_absolute_percentage_error: 19.9241 - val_loss: 0.1354 - val_root_mean_squared_error: 0.3679 - val_mean_absolute_percentage_error: 33.5386
# Epoch 86/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0272 - root_mean_squared_error: 0.1650 - mean_absolute_percentage_error: 19.3573 - val_loss: 0.1375 - val_root_mean_squared_error: 0.3708 - val_mean_absolute_percentage_error: 31.7807
# Epoch 87/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0273 - root_mean_squared_error: 0.1651 - mean_absolute_percentage_error: 19.6133 - val_loss: 0.1293 - val_root_mean_squared_error: 0.3596 - val_mean_absolute_percentage_error: 31.0993
# Epoch 88/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0252 - root_mean_squared_error: 0.1588 - mean_absolute_percentage_error: 18.9915 - val_loss: 0.1302 - val_root_mean_squared_error: 0.3609 - val_mean_absolute_percentage_error: 31.4728
# Epoch 89/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0248 - root_mean_squared_error: 0.1576 - mean_absolute_percentage_error: 19.8842 - val_loss: 0.1355 - val_root_mean_squared_error: 0.3680 - val_mean_absolute_percentage_error: 30.8986
# Epoch 90/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0265 - root_mean_squared_error: 0.1629 - mean_absolute_percentage_error: 19.6704 - val_loss: 0.1307 - val_root_mean_squared_error: 0.3615 - val_mean_absolute_percentage_error: 29.9720
# Epoch 91/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0261 - root_mean_squared_error: 0.1614 - mean_absolute_percentage_error: 19.5312 - val_loss: 0.1307 - val_root_mean_squared_error: 0.3615 - val_mean_absolute_percentage_error: 30.7671
# Epoch 92/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0257 - root_mean_squared_error: 0.1603 - mean_absolute_percentage_error: 19.5867 - val_loss: 0.1307 - val_root_mean_squared_error: 0.3615 - val_mean_absolute_percentage_error: 31.5116
# Epoch 93/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0255 - root_mean_squared_error: 0.1596 - mean_absolute_percentage_error: 19.3992 - val_loss: 0.1355 - val_root_mean_squared_error: 0.3681 - val_mean_absolute_percentage_error: 30.3617
# Epoch 94/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0236 - root_mean_squared_error: 0.1536 - mean_absolute_percentage_error: 19.1353 - val_loss: 0.1312 - val_root_mean_squared_error: 0.3622 - val_mean_absolute_percentage_error: 29.4334
# Epoch 95/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0244 - root_mean_squared_error: 0.1563 - mean_absolute_percentage_error: 18.7792 - val_loss: 0.1430 - val_root_mean_squared_error: 0.3782 - val_mean_absolute_percentage_error: 34.3799
# Epoch 96/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0256 - root_mean_squared_error: 0.1601 - mean_absolute_percentage_error: 19.4184 - val_loss: 0.1321 - val_root_mean_squared_error: 0.3635 - val_mean_absolute_percentage_error: 29.2172
# Epoch 97/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0234 - root_mean_squared_error: 0.1530 - mean_absolute_percentage_error: 18.6497 - val_loss: 0.1367 - val_root_mean_squared_error: 0.3697 - val_mean_absolute_percentage_error: 34.0638
# Epoch 98/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0231 - root_mean_squared_error: 0.1520 - mean_absolute_percentage_error: 18.7184 - val_loss: 0.1370 - val_root_mean_squared_error: 0.3701 - val_mean_absolute_percentage_error: 32.1615
# Epoch 99/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0234 - root_mean_squared_error: 0.1531 - mean_absolute_percentage_error: 18.7796 - val_loss: 0.1322 - val_root_mean_squared_error: 0.3636 - val_mean_absolute_percentage_error: 29.0296
# Epoch 100/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0229 - root_mean_squared_error: 0.1515 - mean_absolute_percentage_error: 18.5359 - val_loss: 0.1292 - val_root_mean_squared_error: 0.3595 - val_mean_absolute_percentage_error: 31.9741
# Epoch 101/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0232 - root_mean_squared_error: 0.1522 - mean_absolute_percentage_error: 18.0057 - val_loss: 0.1336 - val_root_mean_squared_error: 0.3654 - val_mean_absolute_percentage_error: 32.3702
# Epoch 102/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0226 - root_mean_squared_error: 0.1503 - mean_absolute_percentage_error: 18.3944 - val_loss: 0.1387 - val_root_mean_squared_error: 0.3725 - val_mean_absolute_percentage_error: 33.3117
# Epoch 103/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0232 - root_mean_squared_error: 0.1522 - mean_absolute_percentage_error: 18.6000 - val_loss: 0.1354 - val_root_mean_squared_error: 0.3679 - val_mean_absolute_percentage_error: 31.0172
# Epoch 104/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0217 - root_mean_squared_error: 0.1473 - mean_absolute_percentage_error: 18.1274 - val_loss: 0.1329 - val_root_mean_squared_error: 0.3645 - val_mean_absolute_percentage_error: 30.4575
# Epoch 105/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0209 - root_mean_squared_error: 0.1445 - mean_absolute_percentage_error: 18.1415 - val_loss: 0.1285 - val_root_mean_squared_error: 0.3585 - val_mean_absolute_percentage_error: 30.0141
# Epoch 106/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0217 - root_mean_squared_error: 0.1473 - mean_absolute_percentage_error: 18.4642 - val_loss: 0.1402 - val_root_mean_squared_error: 0.3744 - val_mean_absolute_percentage_error: 35.5446
# Epoch 107/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0217 - root_mean_squared_error: 0.1473 - mean_absolute_percentage_error: 18.0956 - val_loss: 0.1314 - val_root_mean_squared_error: 0.3625 - val_mean_absolute_percentage_error: 29.9476
# Epoch 108/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0218 - root_mean_squared_error: 0.1476 - mean_absolute_percentage_error: 17.6839 - val_loss: 0.1308 - val_root_mean_squared_error: 0.3617 - val_mean_absolute_percentage_error: 27.3535
# Epoch 109/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0220 - root_mean_squared_error: 0.1485 - mean_absolute_percentage_error: 18.3219 - val_loss: 0.1429 - val_root_mean_squared_error: 0.3781 - val_mean_absolute_percentage_error: 30.2380
# Epoch 110/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0245 - root_mean_squared_error: 0.1565 - mean_absolute_percentage_error: 18.4196 - val_loss: 0.1297 - val_root_mean_squared_error: 0.3601 - val_mean_absolute_percentage_error: 28.7407
# Epoch 111/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0219 - root_mean_squared_error: 0.1481 - mean_absolute_percentage_error: 17.6708 - val_loss: 0.1310 - val_root_mean_squared_error: 0.3619 - val_mean_absolute_percentage_error: 30.6117
# Epoch 112/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0200 - root_mean_squared_error: 0.1414 - mean_absolute_percentage_error: 17.1100 - val_loss: 0.1398 - val_root_mean_squared_error: 0.3739 - val_mean_absolute_percentage_error: 32.0125
# Epoch 113/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0215 - root_mean_squared_error: 0.1466 - mean_absolute_percentage_error: 17.8764 - val_loss: 0.1361 - val_root_mean_squared_error: 0.3690 - val_mean_absolute_percentage_error: 30.8582
# Epoch 114/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0198 - root_mean_squared_error: 0.1407 - mean_absolute_percentage_error: 17.5443 - val_loss: 0.1319 - val_root_mean_squared_error: 0.3632 - val_mean_absolute_percentage_error: 29.0552
# Epoch 115/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0207 - root_mean_squared_error: 0.1440 - mean_absolute_percentage_error: 17.7139 - val_loss: 0.1378 - val_root_mean_squared_error: 0.3712 - val_mean_absolute_percentage_error: 31.0167
# Epoch 116/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0220 - root_mean_squared_error: 0.1484 - mean_absolute_percentage_error: 18.2623 - val_loss: 0.1261 - val_root_mean_squared_error: 0.3551 - val_mean_absolute_percentage_error: 28.3381
# Epoch 117/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0201 - root_mean_squared_error: 0.1417 - mean_absolute_percentage_error: 17.2991 - val_loss: 0.1338 - val_root_mean_squared_error: 0.3657 - val_mean_absolute_percentage_error: 28.9909
# Epoch 118/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0200 - root_mean_squared_error: 0.1414 - mean_absolute_percentage_error: 17.2579 - val_loss: 0.1359 - val_root_mean_squared_error: 0.3687 - val_mean_absolute_percentage_error: 30.5266
# Epoch 119/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0189 - root_mean_squared_error: 0.1375 - mean_absolute_percentage_error: 17.2278 - val_loss: 0.1337 - val_root_mean_squared_error: 0.3656 - val_mean_absolute_percentage_error: 32.3009
# Epoch 120/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0206 - root_mean_squared_error: 0.1435 - mean_absolute_percentage_error: 17.5952 - val_loss: 0.1280 - val_root_mean_squared_error: 0.3578 - val_mean_absolute_percentage_error: 29.8126
# Epoch 121/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0219 - root_mean_squared_error: 0.1479 - mean_absolute_percentage_error: 17.1300 - val_loss: 0.1381 - val_root_mean_squared_error: 0.3717 - val_mean_absolute_percentage_error: 30.0326
# Epoch 122/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0202 - root_mean_squared_error: 0.1423 - mean_absolute_percentage_error: 17.3571 - val_loss: 0.1264 - val_root_mean_squared_error: 0.3555 - val_mean_absolute_percentage_error: 27.4407
# Epoch 123/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0185 - root_mean_squared_error: 0.1361 - mean_absolute_percentage_error: 17.0592 - val_loss: 0.1327 - val_root_mean_squared_error: 0.3642 - val_mean_absolute_percentage_error: 29.7556
# Epoch 124/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0190 - root_mean_squared_error: 0.1378 - mean_absolute_percentage_error: 17.3847 - val_loss: 0.1303 - val_root_mean_squared_error: 0.3610 - val_mean_absolute_percentage_error: 28.8372
# Epoch 125/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0179 - root_mean_squared_error: 0.1339 - mean_absolute_percentage_error: 16.7667 - val_loss: 0.1423 - val_root_mean_squared_error: 0.3772 - val_mean_absolute_percentage_error: 31.2876
# Epoch 126/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0199 - root_mean_squared_error: 0.1409 - mean_absolute_percentage_error: 17.4913 - val_loss: 0.1349 - val_root_mean_squared_error: 0.3673 - val_mean_absolute_percentage_error: 29.4350
# Epoch 127/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0185 - root_mean_squared_error: 0.1360 - mean_absolute_percentage_error: 17.5424 - val_loss: 0.1341 - val_root_mean_squared_error: 0.3662 - val_mean_absolute_percentage_error: 31.3866
# Epoch 128/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0183 - root_mean_squared_error: 0.1351 - mean_absolute_percentage_error: 16.8451 - val_loss: 0.1303 - val_root_mean_squared_error: 0.3609 - val_mean_absolute_percentage_error: 26.5108
# Epoch 129/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0180 - root_mean_squared_error: 0.1340 - mean_absolute_percentage_error: 16.8295 - val_loss: 0.1337 - val_root_mean_squared_error: 0.3657 - val_mean_absolute_percentage_error: 29.8612
# Epoch 130/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0207 - root_mean_squared_error: 0.1438 - mean_absolute_percentage_error: 17.0669 - val_loss: 0.1284 - val_root_mean_squared_error: 0.3584 - val_mean_absolute_percentage_error: 31.1410
# Epoch 131/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0185 - root_mean_squared_error: 0.1358 - mean_absolute_percentage_error: 17.2505 - val_loss: 0.1304 - val_root_mean_squared_error: 0.3611 - val_mean_absolute_percentage_error: 28.8874
# Epoch 132/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0181 - root_mean_squared_error: 0.1344 - mean_absolute_percentage_error: 16.5348 - val_loss: 0.1341 - val_root_mean_squared_error: 0.3662 - val_mean_absolute_percentage_error: 32.1944
# Epoch 133/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0187 - root_mean_squared_error: 0.1367 - mean_absolute_percentage_error: 17.0082 - val_loss: 0.1287 - val_root_mean_squared_error: 0.3587 - val_mean_absolute_percentage_error: 29.4666
# Epoch 134/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0168 - root_mean_squared_error: 0.1297 - mean_absolute_percentage_error: 15.8818 - val_loss: 0.1298 - val_root_mean_squared_error: 0.3603 - val_mean_absolute_percentage_error: 27.5040
# Epoch 135/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0180 - root_mean_squared_error: 0.1341 - mean_absolute_percentage_error: 16.4586 - val_loss: 0.1289 - val_root_mean_squared_error: 0.3591 - val_mean_absolute_percentage_error: 29.7387
# Epoch 136/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0189 - root_mean_squared_error: 0.1376 - mean_absolute_percentage_error: 16.6595 - val_loss: 0.1279 - val_root_mean_squared_error: 0.3577 - val_mean_absolute_percentage_error: 28.8313
# Epoch 137/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0173 - root_mean_squared_error: 0.1317 - mean_absolute_percentage_error: 16.5637 - val_loss: 0.1334 - val_root_mean_squared_error: 0.3652 - val_mean_absolute_percentage_error: 30.4557
# Epoch 138/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0179 - root_mean_squared_error: 0.1338 - mean_absolute_percentage_error: 16.6111 - val_loss: 0.1327 - val_root_mean_squared_error: 0.3643 - val_mean_absolute_percentage_error: 29.8236
# Epoch 139/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0176 - root_mean_squared_error: 0.1328 - mean_absolute_percentage_error: 16.3603 - val_loss: 0.1320 - val_root_mean_squared_error: 0.3633 - val_mean_absolute_percentage_error: 29.5059
# Epoch 140/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0171 - root_mean_squared_error: 0.1306 - mean_absolute_percentage_error: 16.0217 - val_loss: 0.1295 - val_root_mean_squared_error: 0.3599 - val_mean_absolute_percentage_error: 30.7867
# Epoch 141/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0170 - root_mean_squared_error: 0.1304 - mean_absolute_percentage_error: 17.0184 - val_loss: 0.1275 - val_root_mean_squared_error: 0.3571 - val_mean_absolute_percentage_error: 29.6550
# Epoch 142/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0185 - root_mean_squared_error: 0.1362 - mean_absolute_percentage_error: 16.8699 - val_loss: 0.1303 - val_root_mean_squared_error: 0.3610 - val_mean_absolute_percentage_error: 25.6802
# Epoch 143/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0217 - root_mean_squared_error: 0.1474 - mean_absolute_percentage_error: 16.7661 - val_loss: 0.1296 - val_root_mean_squared_error: 0.3600 - val_mean_absolute_percentage_error: 28.6981
# Epoch 144/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0167 - root_mean_squared_error: 0.1294 - mean_absolute_percentage_error: 16.1593 - val_loss: 0.1283 - val_root_mean_squared_error: 0.3582 - val_mean_absolute_percentage_error: 29.1002
# Epoch 145/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0158 - root_mean_squared_error: 0.1257 - mean_absolute_percentage_error: 15.7080 - val_loss: 0.1299 - val_root_mean_squared_error: 0.3604 - val_mean_absolute_percentage_error: 28.3117
# Epoch 146/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0170 - root_mean_squared_error: 0.1303 - mean_absolute_percentage_error: 15.8260 - val_loss: 0.1286 - val_root_mean_squared_error: 0.3586 - val_mean_absolute_percentage_error: 28.2297
# Epoch 147/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0157 - root_mean_squared_error: 0.1252 - mean_absolute_percentage_error: 15.7948 - val_loss: 0.1300 - val_root_mean_squared_error: 0.3606 - val_mean_absolute_percentage_error: 27.9226
# Epoch 148/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0166 - root_mean_squared_error: 0.1290 - mean_absolute_percentage_error: 15.7945 - val_loss: 0.1278 - val_root_mean_squared_error: 0.3575 - val_mean_absolute_percentage_error: 29.1878
# Epoch 149/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0176 - root_mean_squared_error: 0.1325 - mean_absolute_percentage_error: 15.9374 - val_loss: 0.1309 - val_root_mean_squared_error: 0.3618 - val_mean_absolute_percentage_error: 33.0027
# Epoch 150/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0175 - root_mean_squared_error: 0.1325 - mean_absolute_percentage_error: 16.1595 - val_loss: 0.1257 - val_root_mean_squared_error: 0.3545 - val_mean_absolute_percentage_error: 29.1857
# Epoch 151/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0156 - root_mean_squared_error: 0.1248 - mean_absolute_percentage_error: 15.6914 - val_loss: 0.1300 - val_root_mean_squared_error: 0.3606 - val_mean_absolute_percentage_error: 29.0140
# Epoch 152/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0164 - root_mean_squared_error: 0.1282 - mean_absolute_percentage_error: 15.9881 - val_loss: 0.1317 - val_root_mean_squared_error: 0.3629 - val_mean_absolute_percentage_error: 31.1821
# Epoch 153/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0148 - root_mean_squared_error: 0.1217 - mean_absolute_percentage_error: 15.4800 - val_loss: 0.1355 - val_root_mean_squared_error: 0.3681 - val_mean_absolute_percentage_error: 27.8513
# Epoch 154/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0166 - root_mean_squared_error: 0.1288 - mean_absolute_percentage_error: 15.8354 - val_loss: 0.1312 - val_root_mean_squared_error: 0.3622 - val_mean_absolute_percentage_error: 29.6386
# Epoch 155/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0168 - root_mean_squared_error: 0.1298 - mean_absolute_percentage_error: 15.8519 - val_loss: 0.1304 - val_root_mean_squared_error: 0.3611 - val_mean_absolute_percentage_error: 27.8741
# Epoch 156/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0169 - root_mean_squared_error: 0.1298 - mean_absolute_percentage_error: 15.6704 - val_loss: 0.1296 - val_root_mean_squared_error: 0.3599 - val_mean_absolute_percentage_error: 32.1714
# Epoch 157/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0178 - root_mean_squared_error: 0.1333 - mean_absolute_percentage_error: 15.5509 - val_loss: 0.1333 - val_root_mean_squared_error: 0.3651 - val_mean_absolute_percentage_error: 30.7459
# Epoch 158/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0171 - root_mean_squared_error: 0.1309 - mean_absolute_percentage_error: 15.9046 - val_loss: 0.1288 - val_root_mean_squared_error: 0.3589 - val_mean_absolute_percentage_error: 28.7583
# Epoch 159/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0153 - root_mean_squared_error: 0.1238 - mean_absolute_percentage_error: 15.5973 - val_loss: 0.1274 - val_root_mean_squared_error: 0.3570 - val_mean_absolute_percentage_error: 26.9190
# Epoch 160/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214 - mean_absolute_percentage_error: 15.0020 - val_loss: 0.1260 - val_root_mean_squared_error: 0.3549 - val_mean_absolute_percentage_error: 27.3218
# Epoch 161/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0145 - root_mean_squared_error: 0.1203 - mean_absolute_percentage_error: 14.9738 - val_loss: 0.1331 - val_root_mean_squared_error: 0.3648 - val_mean_absolute_percentage_error: 28.4583
# Epoch 162/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0147 - root_mean_squared_error: 0.1214 - mean_absolute_percentage_error: 15.2927 - val_loss: 0.1323 - val_root_mean_squared_error: 0.3638 - val_mean_absolute_percentage_error: 30.9195
# Epoch 163/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0151 - root_mean_squared_error: 0.1230 - mean_absolute_percentage_error: 15.5782 - val_loss: 0.1346 - val_root_mean_squared_error: 0.3669 - val_mean_absolute_percentage_error: 31.1085
# Epoch 164/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0161 - root_mean_squared_error: 0.1268 - mean_absolute_percentage_error: 15.4452 - val_loss: 0.1340 - val_root_mean_squared_error: 0.3661 - val_mean_absolute_percentage_error: 30.4853
# Epoch 165/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0161 - root_mean_squared_error: 0.1270 - mean_absolute_percentage_error: 15.7863 - val_loss: 0.1348 - val_root_mean_squared_error: 0.3671 - val_mean_absolute_percentage_error: 32.2032
# Epoch 166/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0160 - root_mean_squared_error: 0.1265 - mean_absolute_percentage_error: 15.0097 - val_loss: 0.1303 - val_root_mean_squared_error: 0.3610 - val_mean_absolute_percentage_error: 29.5556
# Epoch 167/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0169 - root_mean_squared_error: 0.1299 - mean_absolute_percentage_error: 15.9676 - val_loss: 0.1305 - val_root_mean_squared_error: 0.3613 - val_mean_absolute_percentage_error: 30.2446
# Epoch 168/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0154 - root_mean_squared_error: 0.1241 - mean_absolute_percentage_error: 15.3502 - val_loss: 0.1210 - val_root_mean_squared_error: 0.3479 - val_mean_absolute_percentage_error: 28.9114
# Epoch 169/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0163 - root_mean_squared_error: 0.1277 - mean_absolute_percentage_error: 15.1776 - val_loss: 0.1275 - val_root_mean_squared_error: 0.3571 - val_mean_absolute_percentage_error: 28.7021
# Epoch 170/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0151 - root_mean_squared_error: 0.1227 - mean_absolute_percentage_error: 14.9478 - val_loss: 0.1251 - val_root_mean_squared_error: 0.3536 - val_mean_absolute_percentage_error: 31.4142
# Epoch 171/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0157 - root_mean_squared_error: 0.1255 - mean_absolute_percentage_error: 15.5395 - val_loss: 0.1285 - val_root_mean_squared_error: 0.3585 - val_mean_absolute_percentage_error: 27.6653
# Epoch 172/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0162 - root_mean_squared_error: 0.1272 - mean_absolute_percentage_error: 15.2596 - val_loss: 0.1303 - val_root_mean_squared_error: 0.3610 - val_mean_absolute_percentage_error: 32.3411
# Epoch 173/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232 - mean_absolute_percentage_error: 14.5161 - val_loss: 0.1295 - val_root_mean_squared_error: 0.3598 - val_mean_absolute_percentage_error: 27.7214
# Epoch 174/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0161 - root_mean_squared_error: 0.1268 - mean_absolute_percentage_error: 15.1227 - val_loss: 0.1280 - val_root_mean_squared_error: 0.3578 - val_mean_absolute_percentage_error: 29.6974
# Epoch 175/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0140 - root_mean_squared_error: 0.1185 - mean_absolute_percentage_error: 14.3212 - val_loss: 0.1243 - val_root_mean_squared_error: 0.3526 - val_mean_absolute_percentage_error: 27.9897
# Epoch 176/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0142 - root_mean_squared_error: 0.1193 - mean_absolute_percentage_error: 14.8303 - val_loss: 0.1236 - val_root_mean_squared_error: 0.3516 - val_mean_absolute_percentage_error: 29.7673
# Epoch 177/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194 - mean_absolute_percentage_error: 15.1919 - val_loss: 0.1280 - val_root_mean_squared_error: 0.3577 - val_mean_absolute_percentage_error: 28.9792
# Epoch 178/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0149 - root_mean_squared_error: 0.1221 - mean_absolute_percentage_error: 14.9546 - val_loss: 0.1233 - val_root_mean_squared_error: 0.3512 - val_mean_absolute_percentage_error: 27.0971
# Epoch 179/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - mean_absolute_percentage_error: 14.4538 - val_loss: 0.1285 - val_root_mean_squared_error: 0.3585 - val_mean_absolute_percentage_error: 26.7947
# Epoch 180/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0148 - root_mean_squared_error: 0.1216 - mean_absolute_percentage_error: 15.4195 - val_loss: 0.1219 - val_root_mean_squared_error: 0.3492 - val_mean_absolute_percentage_error: 29.0342
# Epoch 181/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0152 - root_mean_squared_error: 0.1232 - mean_absolute_percentage_error: 14.9865 - val_loss: 0.1248 - val_root_mean_squared_error: 0.3532 - val_mean_absolute_percentage_error: 28.0980
# Epoch 182/500
# 325/325 [==============================] - 2s 6ms/step - loss: 0.0160 - root_mean_squared_error: 0.1267 - mean_absolute_percentage_error: 14.7951 - val_loss: 0.1278 - val_root_mean_squared_error: 0.3575 - val_mean_absolute_percentage_error: 28.9094
# Epoch 183/500
# ...
# Epoch 441/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0090 - root_mean_squared_error: 0.0950 - mean_absolute_percentage_error: 10.6256 - val_loss: 0.1091 - val_root_mean_squared_error: 0.3304 - val_mean_absolute_percentage_error: 28.4375
# Epoch 442/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0072 - root_mean_squared_error: 0.0846 - mean_absolute_percentage_error: 10.6802 - val_loss: 0.1074 - val_root_mean_squared_error: 0.3277 - val_mean_absolute_percentage_error: 25.3236
# Epoch 443/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0078 - root_mean_squared_error: 0.0880 - mean_absolute_percentage_error: 11.4231 - val_loss: 0.1049 - val_root_mean_squared_error: 0.3239 - val_mean_absolute_percentage_error: 24.1712
# Epoch 444/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0068 - root_mean_squared_error: 0.0827 - mean_absolute_percentage_error: 9.8911 - val_loss: 0.1083 - val_root_mean_squared_error: 0.3291 - val_mean_absolute_percentage_error: 28.6806
# Epoch 445/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0063 - root_mean_squared_error: 0.0795 - mean_absolute_percentage_error: 10.0553 - val_loss: 0.1041 - val_root_mean_squared_error: 0.3226 - val_mean_absolute_percentage_error: 24.3016
# Epoch 446/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0066 - root_mean_squared_error: 0.0812 - mean_absolute_percentage_error: 10.3915 - val_loss: 0.1083 - val_root_mean_squared_error: 0.3292 - val_mean_absolute_percentage_error: 26.1375
# Epoch 447/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - mean_absolute_percentage_error: 10.6855 - val_loss: 0.1057 - val_root_mean_squared_error: 0.3251 - val_mean_absolute_percentage_error: 24.1861
# Epoch 448/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0090 - root_mean_squared_error: 0.0950 - mean_absolute_percentage_error: 11.2066 - val_loss: 0.1034 - val_root_mean_squared_error: 0.3216 - val_mean_absolute_percentage_error: 25.0487
# Epoch 449/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - mean_absolute_percentage_error: 10.8703 - val_loss: 0.1065 - val_root_mean_squared_error: 0.3264 - val_mean_absolute_percentage_error: 28.6384
# Epoch 450/500
# 325/325 [==============================] - 0s 1ms/step - loss: 0.0067 - root_mean_squared_error: 0.0821 - mean_absolute_percentage_error: 10.6312 - val_loss: 0.1075 - val_root_mean_squared_error: 0.3279 - val_mean_absolute_percentage_error: 25.7055
# Epoch 451/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0068 - root_mean_squared_error: 0.0824 - mean_absolute_percentage_error: 10.7430 - val_loss: 0.1064 - val_root_mean_squared_error: 0.3262 - val_mean_absolute_percentage_error: 25.3552
# Epoch 452/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0065 - root_mean_squared_error: 0.0805 - mean_absolute_percentage_error: 10.1437 - val_loss: 0.1054 - val_root_mean_squared_error: 0.3246 - val_mean_absolute_percentage_error: 26.7410
# Epoch 453/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0068 - root_mean_squared_error: 0.0826 - mean_absolute_percentage_error: 10.3217 - val_loss: 0.1036 - val_root_mean_squared_error: 0.3218 - val_mean_absolute_percentage_error: 25.0727
# Epoch 454/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0064 - root_mean_squared_error: 0.0801 - mean_absolute_percentage_error: 10.1254 - val_loss: 0.1040 - val_root_mean_squared_error: 0.3224 - val_mean_absolute_percentage_error: 24.4956
# Epoch 455/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0066 - root_mean_squared_error: 0.0810 - mean_absolute_percentage_error: 10.4838 - val_loss: 0.1003 - val_root_mean_squared_error: 0.3166 - val_mean_absolute_percentage_error: 24.4117
# Epoch 456/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0085 - root_mean_squared_error: 0.0924 - mean_absolute_percentage_error: 10.8117 - val_loss: 0.1102 - val_root_mean_squared_error: 0.3320 - val_mean_absolute_percentage_error: 24.0503
# Epoch 457/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0091 - root_mean_squared_error: 0.0954 - mean_absolute_percentage_error: 11.7257 - val_loss: 0.1086 - val_root_mean_squared_error: 0.3295 - val_mean_absolute_percentage_error: 27.7111
# Epoch 458/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0070 - root_mean_squared_error: 0.0839 - mean_absolute_percentage_error: 10.6487 - val_loss: 0.1052 - val_root_mean_squared_error: 0.3243 - val_mean_absolute_percentage_error: 23.4550
# Epoch 459/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0071 - root_mean_squared_error: 0.0843 - mean_absolute_percentage_error: 10.5206 - val_loss: 0.1044 - val_root_mean_squared_error: 0.3231 - val_mean_absolute_percentage_error: 24.3240
# Epoch 460/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0069 - root_mean_squared_error: 0.0829 - mean_absolute_percentage_error: 9.7286 - val_loss: 0.1082 - val_root_mean_squared_error: 0.3289 - val_mean_absolute_percentage_error: 23.2870
# Epoch 461/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0069 - root_mean_squared_error: 0.0833 - mean_absolute_percentage_error: 9.9255 - val_loss: 0.1027 - val_root_mean_squared_error: 0.3205 - val_mean_absolute_percentage_error: 24.0969
# Epoch 462/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0063 - root_mean_squared_error: 0.0792 - mean_absolute_percentage_error: 9.8361 - val_loss: 0.1061 - val_root_mean_squared_error: 0.3257 - val_mean_absolute_percentage_error: 23.7837
# Epoch 463/500
# 325/325 [==============================] - 0s 1ms/step - loss: 0.0075 - root_mean_squared_error: 0.0865 - mean_absolute_percentage_error: 10.7291 - val_loss: 0.1076 - val_root_mean_squared_error: 0.3281 - val_mean_absolute_percentage_error: 23.9955
# Epoch 464/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0070 - root_mean_squared_error: 0.0837 - mean_absolute_percentage_error: 10.2754 - val_loss: 0.1038 - val_root_mean_squared_error: 0.3222 - val_mean_absolute_percentage_error: 23.3637
# Epoch 465/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0063 - root_mean_squared_error: 0.0794 - mean_absolute_percentage_error: 9.8633 - val_loss: 0.1057 - val_root_mean_squared_error: 0.3251 - val_mean_absolute_percentage_error: 28.2559
# Epoch 466/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.0862 - mean_absolute_percentage_error: 10.7100 - val_loss: 0.1094 - val_root_mean_squared_error: 0.3308 - val_mean_absolute_percentage_error: 22.6061
# Epoch 467/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0077 - root_mean_squared_error: 0.0876 - mean_absolute_percentage_error: 10.4701 - val_loss: 0.1077 - val_root_mean_squared_error: 0.3281 - val_mean_absolute_percentage_error: 26.5612
# Epoch 468/500
# 325/325 [==============================] - 0s 1ms/step - loss: 0.0066 - root_mean_squared_error: 0.0814 - mean_absolute_percentage_error: 10.4681 - val_loss: 0.1056 - val_root_mean_squared_error: 0.3249 - val_mean_absolute_percentage_error: 26.4864
# Epoch 469/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0070 - root_mean_squared_error: 0.0839 - mean_absolute_percentage_error: 10.4556 - val_loss: 0.1066 - val_root_mean_squared_error: 0.3265 - val_mean_absolute_percentage_error: 24.8635
# Epoch 470/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0063 - root_mean_squared_error: 0.0795 - mean_absolute_percentage_error: 10.1659 - val_loss: 0.1050 - val_root_mean_squared_error: 0.3240 - val_mean_absolute_percentage_error: 24.8112
# Epoch 471/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0061 - root_mean_squared_error: 0.0783 - mean_absolute_percentage_error: 9.9086 - val_loss: 0.1059 - val_root_mean_squared_error: 0.3254 - val_mean_absolute_percentage_error: 23.1532
# Epoch 472/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.0888 - mean_absolute_percentage_error: 10.7116 - val_loss: 0.1028 - val_root_mean_squared_error: 0.3207 - val_mean_absolute_percentage_error: 24.8798
# Epoch 473/500
# 325/325 [==============================] - 0s 1ms/step - loss: 0.0070 - root_mean_squared_error: 0.0838 - mean_absolute_percentage_error: 10.2494 - val_loss: 0.1059 - val_root_mean_squared_error: 0.3254 - val_mean_absolute_percentage_error: 26.2894
# Epoch 474/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.0860 - mean_absolute_percentage_error: 9.8564 - val_loss: 0.1018 - val_root_mean_squared_error: 0.3190 - val_mean_absolute_percentage_error: 23.7954
# Epoch 475/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0068 - root_mean_squared_error: 0.0822 - mean_absolute_percentage_error: 10.9608 - val_loss: 0.1029 - val_root_mean_squared_error: 0.3208 - val_mean_absolute_percentage_error: 26.0535
# Epoch 476/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0079 - root_mean_squared_error: 0.0891 - mean_absolute_percentage_error: 10.5245 - val_loss: 0.1083 - val_root_mean_squared_error: 0.3290 - val_mean_absolute_percentage_error: 25.5895
# Epoch 477/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - mean_absolute_percentage_error: 10.9911 - val_loss: 0.1062 - val_root_mean_squared_error: 0.3259 - val_mean_absolute_percentage_error: 25.8091
# Epoch 478/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0063 - root_mean_squared_error: 0.0795 - mean_absolute_percentage_error: 10.4817 - val_loss: 0.1054 - val_root_mean_squared_error: 0.3246 - val_mean_absolute_percentage_error: 25.3092
# Epoch 479/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0058 - root_mean_squared_error: 0.0764 - mean_absolute_percentage_error: 9.8447 - val_loss: 0.1015 - val_root_mean_squared_error: 0.3186 - val_mean_absolute_percentage_error: 25.4886
# Epoch 480/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0066 - root_mean_squared_error: 0.0812 - mean_absolute_percentage_error: 9.7898 - val_loss: 0.1075 - val_root_mean_squared_error: 0.3279 - val_mean_absolute_percentage_error: 24.9931
# Epoch 481/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0066 - root_mean_squared_error: 0.0813 - mean_absolute_percentage_error: 9.8879 - val_loss: 0.1057 - val_root_mean_squared_error: 0.3252 - val_mean_absolute_percentage_error: 25.9961
# Epoch 482/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0063 - root_mean_squared_error: 0.0793 - mean_absolute_percentage_error: 9.8222 - val_loss: 0.1027 - val_root_mean_squared_error: 0.3204 - val_mean_absolute_percentage_error: 27.1311
# Epoch 483/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0069 - root_mean_squared_error: 0.0829 - mean_absolute_percentage_error: 10.1500 - val_loss: 0.1066 - val_root_mean_squared_error: 0.3264 - val_mean_absolute_percentage_error: 22.0993
# Epoch 484/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0060 - root_mean_squared_error: 0.0774 - mean_absolute_percentage_error: 9.8255 - val_loss: 0.1038 - val_root_mean_squared_error: 0.3221 - val_mean_absolute_percentage_error: 24.1382
# Epoch 485/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0070 - root_mean_squared_error: 0.0835 - mean_absolute_percentage_error: 10.2551 - val_loss: 0.1057 - val_root_mean_squared_error: 0.3251 - val_mean_absolute_percentage_error: 23.6947
# Epoch 486/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0069 - root_mean_squared_error: 0.0830 - mean_absolute_percentage_error: 10.2127 - val_loss: 0.1026 - val_root_mean_squared_error: 0.3203 - val_mean_absolute_percentage_error: 25.4107
# Epoch 487/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0066 - root_mean_squared_error: 0.0811 - mean_absolute_percentage_error: 10.2693 - val_loss: 0.1033 - val_root_mean_squared_error: 0.3214 - val_mean_absolute_percentage_error: 24.8002
# Epoch 488/500
# 325/325 [==============================] - 1s 3ms/step - loss: 0.0068 - root_mean_squared_error: 0.0822 - mean_absolute_percentage_error: 10.1081 - val_loss: 0.1045 - val_root_mean_squared_error: 0.3232 - val_mean_absolute_percentage_error: 23.1323
# Epoch 489/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0063 - root_mean_squared_error: 0.0796 - mean_absolute_percentage_error: 9.8571 - val_loss: 0.1035 - val_root_mean_squared_error: 0.3217 - val_mean_absolute_percentage_error: 24.6177
# Epoch 490/500
# 325/325 [==============================] - 0s 1ms/step - loss: 0.0066 - root_mean_squared_error: 0.0812 - mean_absolute_percentage_error: 10.0485 - val_loss: 0.1059 - val_root_mean_squared_error: 0.3254 - val_mean_absolute_percentage_error: 28.5407
# Epoch 491/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0073 - root_mean_squared_error: 0.0855 - mean_absolute_percentage_error: 10.1487 - val_loss: 0.1046 - val_root_mean_squared_error: 0.3233 - val_mean_absolute_percentage_error: 24.9910
# Epoch 492/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0072 - root_mean_squared_error: 0.0850 - mean_absolute_percentage_error: 10.3014 - val_loss: 0.1027 - val_root_mean_squared_error: 0.3205 - val_mean_absolute_percentage_error: 25.0017
# Epoch 493/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0068 - root_mean_squared_error: 0.0823 - mean_absolute_percentage_error: 10.2073 - val_loss: 0.1034 - val_root_mean_squared_error: 0.3215 - val_mean_absolute_percentage_error: 24.9267
# Epoch 494/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0067 - root_mean_squared_error: 0.0821 - mean_absolute_percentage_error: 9.8396 - val_loss: 0.1040 - val_root_mean_squared_error: 0.3224 - val_mean_absolute_percentage_error: 24.2957
# Epoch 495/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0066 - root_mean_squared_error: 0.0815 - mean_absolute_percentage_error: 10.2821 - val_loss: 0.1021 - val_root_mean_squared_error: 0.3195 - val_mean_absolute_percentage_error: 24.1882
# Epoch 496/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0065 - root_mean_squared_error: 0.0804 - mean_absolute_percentage_error: 9.8859 - val_loss: 0.1015 - val_root_mean_squared_error: 0.3186 - val_mean_absolute_percentage_error: 26.1964
# Epoch 497/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0070 - root_mean_squared_error: 0.0838 - mean_absolute_percentage_error: 10.1869 - val_loss: 0.1026 - val_root_mean_squared_error: 0.3203 - val_mean_absolute_percentage_error: 24.0671
# Epoch 498/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0062 - root_mean_squared_error: 0.0785 - mean_absolute_percentage_error: 9.6149 - val_loss: 0.1127 - val_root_mean_squared_error: 0.3357 - val_mean_absolute_percentage_error: 25.1488
# Epoch 499/500
# 325/325 [==============================] - 1s 2ms/step - loss: 0.0064 - root_mean_squared_error: 0.0802 - mean_absolute_percentage_error: 10.0654 - val_loss: 0.1101 - val_root_mean_squared_error: 0.3318 - val_mean_absolute_percentage_error: 25.2752
# Epoch 500/500
# 325/325 [==============================] - 0s 1ms/step - loss: 0.0079 - root_mean_squared_error: 0.0886 - mean_absolute_percentage_error: 10.4939 - val_loss: 0.1104 - val_root_mean_squared_error: 0.3322 - val_mean_absolute_percentage_error: 25.1363

# %% [markdown]
# ## Gráfico performance

# %%
fig, axis = plt.subplots(2, 2, figsize=(12,10))
axis[0,0].plot(history.history['loss'], label='mse')
axis[0,1].plot(history.history['val_loss'], label='val_mse')
axis[1,0].plot(history.history['mean_absolute_percentage_error'], label='mse')#root_mean_squared_error
axis[1,1].plot(history.history['val_mean_absolute_percentage_error'], label='val_mse')
axis[0,0].set_title("Loss v/s Número de épocas entrenamiento")
axis[0,1].set_title("Loss v/s Número de épocas validación")
axis[1,0].set_title("Otra Metrica v/s Número de épocas entrenamiento")
axis[1,1].set_title("Otra Metrica v/s Número de épocas validación")
plt.tight_layout()
plt.show()

fig, axis = plt.subplots(figsize=(8,5))

plt.plot(history.history['loss'], label='mse')
plt.plot(history.history['val_loss'], label='val_mse')
plt.xlabel("Epochs")
plt.ylabel("MSE")
plt.legend(['MSE', 'val MSE']);
plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn import tree, ensemble
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import mean_squared_error

def RF_model(X, y):
  gsc = GridSearchCV(
      estimator=ensemble.RandomForestRegressor(),
      param_grid={
          'max_depth': range(3, 10),
          'n_estimators': range(10),
          'random_state': [0]
      },
      cv=10,
      scoring='neg_mean_squared_error',
      verbose=0,
      n_jobs=-1)

  grid_result = gsc.fit(X_train, Y_train)
  best_params = grid_result.best_params_

  return best_params

best_params = RF_model(X_train, Y_train)
print("Mejores parámetros (Random Forest):", best_params)

forest = ensemble.RandomForestRegressor(max_depth=best_params["max_depth"], n_estimators=best_params["n_estimators"], random_state=best_params["random_state"])
forest.fit(X_train, Y_train)

predictions = forest.predict(X_test)
print("MSE:", mean_squared_error(Y_test, predictions))

predictions = forest.predict(X_val)
print("MSE val:", mean_squared_error(Y_val, predictions))
# Out:
# Mejores parámetros (Random Forest): {'max_depth': 9, 'n_estimators': 9, 'random_state': 0}
# MSE: 0.06883142774728782
# MSE val: 0.21414963386727093

# %% [markdown]
# ## AdaBoost

# %%
def Ada_model(X, y):
     AB = ensemble.AdaBoostRegressor()      gsc = GridSearchCV         estimator=MultiOutputRegressor(AB          param_gri               'estimator__base_estimator': [DecisionTreeRegressor(max_depth=x) for x in range(3, 1                'estimator__n_estimators': range                 'estimator__random_state      
       ,
          0,
      scoring='neg_mean_square      r',
            e=0,
          jobs=-1)

  grid_result = gsc.fit(X_tr    n, Y_train)
  best_params = grid_result    est_params_

  return best_params

best_params = Ada_model(X_train, Y_train)

AB = ensemble.AdaBoostRegressor()

estimator=MultiOutputRegressor(
    ensemble.AdaBoostRegressor(base_estimator=best_params["estimator__base_estimator"],
    n_estimators=best_params["estimator__n_estimators"],
    random_state=best_params["estimator__random_state"]
    ))

best_params = Ada_m'del(X_train, Y_train)
print("M'jores parámetro
best_estimatorost):", best_params)
max_depth = best_paraase_estimator"].tree_.max_depth
n_estimators = best_params["estimator__n_estimators"]
random_state = best_pada_boost = en_random_state"]
ada_bbasbase_estimator=base_estimatorBoostRegressor(max_depth=max_depth, n_estimators=n_estimators, random_state=random_state)
ada_boost.fit(X_train, Y_train)

predictions = ada_boost.predict(X_test)
print("MSE:", print(mean_squared_error(Y_test, predictions)))

predictions = ada_boost.predict(X_val)
print("MSE val:", print(mean_squared_error(Y_val, predictions)))

# %% [markdown]
# ## Referencias
#
# * Feature Scaling for Machine Learning: Understanding the Difference Between Normalization vs. Standardization: https://www.analyticsvidhya.com/blog/2020/04/feature-scaling-machine-learning-normalization-standardization/
# * How to create a random split cross validation and bagging emsemble for deep learning in keras: https://machinelearningmastery.com/how-to-create-a-random-split-cross-validation-and-bagging-ensemble-for-deep-learning-in-keras/
# * Adaboost ensemble in Python: https://machinelearningmastery.com/adaboost-ensemble-in-python/
# * Notebook ejercicios Tema 12 - Profesor Ricardo Ñanculef

# %%
data = pd.read_csv("sample_data/chile.csv")
data = data.sort_values(by='timestamp')
print(data["timestamp"])
data = data.drop(['data_id','iso', "event_id_cnty", "event_id_no_cnty", "iso3", "country", "region"], axis=1)

for column in data.columns:
  if str(data[column].dtype) != "float":
    data[column] = data[column].astype("|S")

    a = LabelEncoder()
    data[column] = a.fit_transform(data[column])


for c in data.columns:
  data[c] = scale(data[c])

data = data.rename(columns={"admin1": "region"})
print(data.groupby(by="region").count())

last_days = data["timestamp"].unique()
regions = data["region"].unique()
for b in best:
  

print()
# convert series to supervised learning
def series_to_supervised(data, n_in=22, n_out=2):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    
    return agg

a = series_to_supervised(data)
